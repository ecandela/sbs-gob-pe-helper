# %%
import VectorPrecioRentaFija as vp

# %%
df_emisores = vp.get_df_emisores()

# %%
df_emisores.head()
# Out:
#   cboEmisor           Emisor
# 0      9991       A&G Chavin
# 1      2011     ALICORP S.A.
# 2      9967    Atria Energía
# 3      0087  BANCO FALABELLA
# 4      0088       BCO RIPLEY

# %%
df_precios = vp.get_precios_by_isin("PEP21400M064")

# %%
df_precios.head()
# Out:
#         Fecha Precio Limpio Precio Limpio (%) Precio Sucio    Tir
# 0  18/08/2023       995.237            99.524     1000.487  7.145
# 1  17/08/2023       997.050            99.705     1002.106  7.092
# 2  16/08/2023       998.968            99.897     1003.829  7.036
# 3  15/08/2023       998.501            99.850     1003.167  7.050
# 4  14/08/2023       999.851            99.985     1004.323  7.011

# %% [markdown]
# ### Emisor
#
# El valor por defecto de este filtro es vacío, el cual hace que no se aplique este filtro.
#
# | cboEmisor | Descripciòn |
# | ------ | ------ |
# |1000| GOB.CENTRAL|
# |2011| ALICORP S.A.|
# |0087| BANCO FALABELLA|
# |0088| BCO RIPLEY|
# |0001| BCRP|
# |0011| CONTINENTAL|
# |0042| CREDISCOTIA|
# |0003| INTERBANK|
#
# Los emisores disponibles se encuentran en la siguiente página: https://www.sbs.gob.pe/app/pu/CCID/Paginas/vp_rentafija.aspx

# %% [markdown]
# ### Tipo de Moneda
#
# El valor por defecto de este filtro es vacío, el cual hace que no se aplique este filtro.
#
# | cboMoneda | Descripciòn |
# | ------ | ------ |
# | 1 |   Soles|
# | 2 | Soles VAC|
# | 3 | Dolares|

# %% [markdown]
# ### Rating Emisión
#
# El valor por defecto de este filtro es vacío, el cual hace que no se aplique este filtro.
#
# | cboRating |
# | ------ |
# |A|
# |A+|
# |A-|
# |AA|
# |AA+|
# |AA-|
# |AAA|
# |B-|
# |BB|
# |CP-1|
# |CP-1+|
# |CP-1-|
# |CP-2|
# |CP-2+|

# %%
fechaProceso = '21/07/2023'

df = vp.get_vector_precios(fechaProceso=fechaProceso)

# %%
df.columns.tolist()
# Out:
# ['Nemónico',
#  'ISIN/Identif.',
#  'Emisor',
#  'Moneda',
#  'P. Limpio (%)',
#  'TIR %',
#  'Origen(*)',
#  'Spreads',
#  'P. Limpio (monto)',
#  'P. Sucio (monto)',
#  'I.C. (monto)',
#  'F. Emisión',
#  'F. Vencimiento',
#  'Cupón (%)',
#  'Margen Libor (%)',
#  'TIR % S/Opc',
#  'Rating Emisión',
#  'Ult. Cupón',
#  'Prox. Cupón',
#  'Duración',
#  'Var  PLimpio',
#  'Var PSucio',
#  'Var Tir']

# %%
df.head()
# Out:
#      Nemónico ISIN/Identif.      Emisor Moneda P. Limpio (%)  TIR % Origen(*)  \
# 0  CHAVI2CP2C  PEP20950V565  A&G Chavin    USD        99.899  6.268   Mercado
# 1  CHAVI2CP2D  PEP20950V573  A&G Chavin    USD        99.304  6.320   Mercado
# 2  CHAVI2CP2E  PEP20950V581  A&G Chavin    USD        98.466  6.380   Mercado
# 3  CHAVI2CP2F  PEP20950V599  A&G Chavin    USD        96.309  6.468   Mercado
# 4  CHAVI2CP3A  PEP20950V607  A&G Chavin    USD        95.491  6.297   Mercado
#
#   Spreads P. Limpio (monto) P. Sucio (monto)  ... Cupón (%) Margen Libor (%)  \
# 0   1.007           998.987          998.987  ...      .000             .000
# 1   1.011           993.045          993.045  ...      .000             .000
# 2   1.016           984.656          984.656  ...      .000             .000
# 3   1.037           963.093          963.093  ...      .000             .000
# 4   1.050           954.907          954.907  ...      .000             .000
#
#   TIR % S/Opc Rating Emisión  Ult. Cupón Prox. Cupón Duración Var  PLimpio  \
# 0       6.268           CP-2  28/10/2022  27/07/2023     .017         .013
# 1       6.320           CP-2  30/11/2022  31/08/2023     .114        -.006
# 2       6.380           CP-2  20/01/2023  19/10/2023     .250        -.043
# 3       6.468           CP-2  29/05/2023  22/02/2024     .600        -.236
# 4       6.297           CP-2  21/07/2023  18/04/2024     .756         .000
#
#   Var PSucio Var Tir
# 0       .013    .198
# 1      -.006    .210
# 2      -.043    .254
# 3      -.236    .447
# 4       .000    .000
#
# [5 rows x 23 columns]
