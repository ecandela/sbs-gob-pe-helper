# %%
import sbs_gob_pe_helper.VectorPrecioRentaFija as vp 
import pandas as pd
# Out:
# ✅ uc_driver ya está instalado.

# %%
fechaProceso = '05/12/2025'

df = vp.get_vector_precios(fechaProceso=fechaProceso)
# Out:
# 1. Descargando: Renta_Fija_05.12.2025.xls...

# %%
df.head()
# Out:
#      Nemónico ISIN/Identif.           Emisor Moneda  P. Limpio (%)  TIR %  \
# 0  CHAVI2CP3I  PEP20950V680       A&G Chavin    USD         98.429  6.054
# 1  CHAVI3CP1A  PEP20950V698       A&G Chavin    USD         96.366  5.966
# 2  ALIC1DBC3A  PEP21400M114     ALICORP S.A.    PEN        114.542  6.127
# 3  ALICO3BC2A  PEP21400M064     ALICORP S.A.    PEN        104.628  4.608
# 4   BFAL7CD1D  PEP14150Q875  BANCO FALABELLA    PEN         97.885  4.602
#
#   Origen(*)  Spreads  P. Limpio (monto)  P. Sucio (monto)  ...  Cupón (%)  \
# 0       NaN    2.231            984.288           984.288  ...      0.000
# 1       NaN    2.252            963.657           963.657  ...      0.000
# 2       NaN    0.435           1145.419          1182.965  ...      8.094
# 3       NaN    0.440            941.654           965.454  ...      7.000
# 4       NaN    0.609            978.853           978.853  ...      0.000
#
#   Margen Libor (%) TIR % S/Opc  Rating Emisión  Ult. Cupón  Prox. Cupón  \
# ...

# %%
df.columns
# Out:
# Index(['Nemónico', 'ISIN/Identif.', 'Emisor', 'Moneda', 'P. Limpio (%)',
#        'TIR %', 'Origen(*)', 'Spreads', 'P. Limpio (monto)',
#        'P. Sucio (monto)', 'I.C. (monto)', 'F. Emisión', 'F. Vencimiento',
#        'Cupón (%)', 'Margen Libor (%)', 'TIR % S/Opc', 'Rating Emisión',
#        'Ult. Cupón', 'Prox. Cupón', 'Duración', 'Var PLimpio', 'Var PSucio',
#        'Var Tir'],
#       dtype='object')

# %%
df_emisores = vp.get_df_emisores(fechaProceso=fechaProceso)
df_emisores
# Out:
# 1. Descargando: Renta_Fija_05.12.2025.xls...
#              Emisor
# 0        A&G Chavin
# 1      ALICORP S.A.
# 2   BANCO FALABELLA
# 3        BCO RIPLEY
# 4              BCRP
# 5    Banco BCI Peru
# 6   Banco Pichincha
# 7   Bosques Amazóni
# 8     CMAC Arequipa
# 9     CMAC Huancayo
# 10           COFIDE
# 11      CONTINENTAL
# 12       Caja Cusco
# 13         Cineplex
# 14  Compartamos Ban
# 15  Compartamos Fin
# 16  Credicorp Capit
# 17      EDP San Con
# 18     ElectroDunas
# 19  Engie Energía P
# 20         FacTotal
# 21  Financiera Efec
# 22  Fond Mivivienda
# 23           GLORIA
# 24         GNB Perú
# 25      GOB.CENTRAL
# 26          H2Olmos
# 27   Huascacocha FL
# 28         INCIMMET
# 29   INTERAMERICANO
# 30        INTERBANK
# 31      INTERSEGURO
# 32         Inverfal
# 33      JAIME ROJAS
# 34     Jockey Plaza
# 35        LA NACION
# 36       LEAS TOTAL
# 37     LOS PORTALES
# 38      LUZ DEL SUR
# 39   Línea Amarilla
# 40          MIBANCO
# 41          Norvial
# ...

# %%
df_precios = vp.get_precios_by_isin("PEP21400M064")

# %%
df_precios.head()
# Out:
#         Fecha Precio Limpio Precio Limpio (%) Precio Sucio    Tir
# 0  05/12/2025       941.654           104.628      965.454  4.608
# 1  04/12/2025       941.390           104.599      965.015  4.625
# 2  03/12/2025       941.061           104.562      964.511  4.646
# 3  02/12/2025       940.835           104.537      964.110  4.662
# 4  01/12/2025       940.921           104.547      964.021  4.660

# %% [markdown]
# ### Emisor
#
# El valor por defecto de este filtro es vacío, el cual hace que no se aplique este filtro.
#
# | cboEmisor | Descripciòn |
# | ------ | ------ |
# |1000| GOB.CENTRAL|
# |2011| ALICORP S.A.|
# |0087| BANCO FALABELLA|
# |0088| BCO RIPLEY|
# |0001| BCRP|
# |0011| CONTINENTAL|
# |0042| CREDISCOTIA|
# |0003| INTERBANK|
#
# Los emisores disponibles se encuentran en la siguiente página: https://www.sbs.gob.pe/app/pu/CCID/Paginas/vp_rentafija.aspx

# %% [markdown]
# ### Tipo de Moneda
#
# El valor por defecto de este filtro es vacío, el cual hace que no se aplique este filtro.
#
# | cboMoneda | Descripciòn |
# | ------ | ------ |
# | 1 |   Soles|
# | 2 | Soles VAC|
# | 3 | Dolares|

# %% [markdown]
# ### Rating Emisión
#
# El valor por defecto de este filtro es vacío, el cual hace que no se aplique este filtro.
#
# | cboRating |
# | ------ |
# |A|
# |A+|
# |A-|
# |AA|
# |AA+|
# |AA-|
# |AAA|
# |BBB-|
# |B-|
# |BB|
# |CP-1|
# |CP-1+|
# |CP-1-|
# |CP-2|
# |CP-2+|

# %%
fechaProceso = '04/12/2025'

df = vp.get_vector_precios(fechaProceso=fechaProceso)
# Out:
# 1. Descargando: Renta_Fija_04.12.2025.xls...

# %%
df.head()
# Out:
#      Nemónico ISIN/Identif.           Emisor Moneda  P. Limpio (%)  TIR %  \
# 0  CHAVI2CP3I  PEP20950V680       A&G Chavin    USD         98.410  6.064
# 1  CHAVI3CP1A  PEP20950V698       A&G Chavin    USD         96.350  5.966
# 2  ALIC1DBC3A  PEP21400M114     ALICORP S.A.    PEN        114.322  6.155
# 3  ALICO3BC2A  PEP21400M064     ALICORP S.A.    PEN        104.599  4.625
# 4   BFAL7CD1D  PEP14150Q875  BANCO FALABELLA    PEN         97.871  4.608
#
#   Origen(*)  Spreads  P. Limpio (monto)  P. Sucio (monto)  ...  Cupón (%)  \
# 0       NaN    2.231            984.102           984.102  ...      0.000
# 1       NaN    2.252            963.501           963.501  ...      0.000
# 2       NaN    0.435           1143.221          1180.542  ...      8.094
# 3       NaN    0.440            941.390           965.015  ...      7.000
# 4       NaN    0.609            978.708           978.708  ...      0.000
#
#   Margen Libor (%) TIR % S/Opc  Rating Emisión  Ult. Cupón  Prox. Cupón  \
# ...
