# %%
import sbs_gob_pe_helper.IndiceSpreadsCorporativo as isc

# %%
tpCurva = 'CCPSS'
fInicial = '14/12/2006'
fFinal = '29/01/2025'

df_isc = isc.get_indice_spreads_corporativo(tipoCurva=tpCurva,fechaInicio=fInicial, fechaFin=fFinal)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File e:\proyectos\sbs-gob-pe-helper\sbs_gob_pe_helper\IndiceSpreadsCorporativo.py:33, in get_indice_spreads_corporativo(tipoCurva, fechaInicio, fechaFin)
#      32 try:
# ---> 33     tablas = pd.read_html(url, flavor='bs4')
#      34     df_raw = tablas[0]
#
# File c:\Users\USER\anaconda3\envs\sbs-helper\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\envs\sbs-helper\lib\site-packages\pandas\io\html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
#    1203 io = stringify_path(io)
# -> 1205 return _parse(
#    1206     flavor=flavor,
#    1207     io=io,
#    1208     match=match,
#    1209     header=header,
#    1210     index_col=index_col,
#    1211     skiprows=skiprows,
#    1212     parse_dates=parse_dates,
#    1213     thousands=thousands,
#    1214     attrs=attrs,
#    1215     encoding=encoding,
#    1216     decimal=decimal,
#    1217     converters=converters,
#    1218     na_values=na_values,
#    1219     keep_default_na=keep_default_na,
#    1220     displayed_only=displayed_only,
#    1221     extract_links=extract_links,
#    1222 )
#
# File c:\Users\USER\anaconda3\envs\sbs-helper\lib\site-packages\pandas\io\html.py:982, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, **kwargs)
#     981 for flav in flavor:
# --> 982     parser = _parser_dispatch(flav)
#     983     p = parser(io, compiled_match, attrs, encoding, displayed_only, extract_links)
#
# File c:\Users\USER\anaconda3\envs\sbs-helper\lib\site-packages\pandas\io\html.py:931, in _parser_dispatch(flavor)
#     930 if not _HAS_HTML5LIB:
# --> 931     raise ImportError("html5lib not found, please install it")
#     932 if not _HAS_BS4:
#
# ImportError: html5lib not found, please install it
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 5
#       2 fInicial = '14/12/2006'
#       3 fFinal = '29/01/2025'
# ----> 5 df_isc = isc.get_indice_spreads_corporativo(tipoCurva=tpCurva,fechaInicio=fInicial, fechaFin=fFinal)
#
# File e:\proyectos\sbs-gob-pe-helper\sbs_gob_pe_helper\IndiceSpreadsCorporativo.py:95, in get_indice_spreads_corporativo(tipoCurva, fechaInicio, fechaFin)
#      90     return df[cols]
#      92 except Exception as e:
#      93     # CAMBIO: Lanza el error hacia arriba encapsulándolo, en lugar de devolver un string.
#      94     # 'from e' mantiene el rastro original del error para que sepas qué pasó exactamente.
# ---> 95     raise RuntimeError(f"Error en el proceso: {str(e)}") from e
#
# RuntimeError: Error en el proceso: html5lib not found, please install it

# %%
df_isc.head()
# Out:
#   Fecha Visual Fecha de Proceso Tipo de Curva Clasificación Indice de Spread
# 0   14/12/2006       2006-12-14         CCPSS             1           0.2348
# 1   15/12/2006       2006-12-15         CCPSS             1           0.2348
# 2   16/12/2006       2006-12-16         CCPSS             1           0.2348
# 3   17/12/2006       2006-12-17         CCPSS             1           0.2348
# 4   18/12/2006       2006-12-18         CCPSS             1           0.2348
